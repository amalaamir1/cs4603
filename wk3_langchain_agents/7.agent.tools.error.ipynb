# %% [markdown]
# ## Tool Error Handling
#
# Tools fail. APIs time out, users pass bad inputs, divisions by zero happen.
# Without proper error handling:
# * An unhandled exception crashes the entire agent run
# * The LLM never learns *why* a tool failed and cannot recover
#
# The key principle: **tools should never raise unhandled exceptions**.
# Return a descriptive error string *or* raise `ToolException` — both give the LLM
# the context it needs to respond sensibly.
#
# **Topics covered:**
# * Naive tool — what happens when it crashes
# * Strategy 1: return error strings from the tool
# * Strategy 2: raise `ToolException` (caught automatically by the agent)
# * Comparing how the LLM responds with and without error context
# * Defensive tool design checklist

# %%
# %run langchain_common.py
# Out:
# C:\Users\akhawaja\git\cs4603\wk3_langchain_agents\langchain_common.py:12: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.vectorstores import FAISS
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %% [markdown]
# ## 1. The problem — an unguarded tool
#
# Let's build a tool that crashes on bad input and see what happens.

# %%
from pydantic import BaseModel, Field

class DivideInput(BaseModel):
    a: float = Field(description="The numerator")
    b: float = Field(description="The denominator")

@tool(args_schema=DivideInput)
def divide_naive(a: float, b: float) -> float:
    """Divide a by b."""
    return a / b  # will crash if b == 0

# Direct invocation — crashes
try:
    print(divide_naive.invoke({"a": 10, "b": 0}))
except ZeroDivisionError as e:
    print(f"Exception raised: {e}")
# Out:
# Exception raised: division by zero

# %% [markdown]
# ## 2. Strategy 1 — return an error string
#
# The simplest fix: catch the error inside the tool and return a human-readable message.
# The LLM receives this string as the tool result and can explain the issue to the user.

# %%
@tool(args_schema=DivideInput)
def divide_safe(a: float, b: float) -> str:
    """Divide a by b. Returns an error message if b is zero."""
    if b == 0:
        return "Error: cannot divide by zero. Please provide a non-zero denominator."
    return str(a / b)

# Safe invocation
print(divide_safe.invoke({"a": 10, "b": 2}))
print(divide_safe.invoke({"a": 10, "b": 0}))
# Out:
# 5.0
# Error: cannot divide by zero. Please provide a non-zero denominator.

# %%
# The agent now receives the error message and can explain it to the user
agent = create_agent(llm_noreason, [divide_safe])

result = agent.invoke({"messages": [HumanMessage(content="What is 42 divided by 0?")]})
print(result["messages"][-1].content)
# Out:
# Division by zero is undefined in mathematics. Therefore, 42 divided by 0 has no result.

# %% [markdown]
# ## 3. Strategy 2 — raise `ToolException`
#
# `ToolException` is LangChain's dedicated exception for tool errors.
# The prebuilt agent (`create_react_agent`) catches it automatically and
# converts it into a `ToolMessage` with `is_error=True`.
# The LLM sees the error text and can decide how to proceed.

# %%
from langchain_core.tools import ToolException

class StockInput(BaseModel):
    ticker: str = Field(description="Stock ticker symbol, e.g. 'AAPL'")

KNOWN_STOCKS = {"AAPL": 189.50, "GOOGL": 175.30, "MSFT": 415.20}

@tool(args_schema=StockInput)
def get_stock_price(ticker: str) -> str:
    """Get the latest stock price for a given ticker symbol."""
    ticker = ticker.upper()
    if ticker not in KNOWN_STOCKS:
        raise ToolException(
            f"Ticker '{ticker}' not found. Available tickers: {', '.join(KNOWN_STOCKS)}"
        )
    return f"{ticker}: ${KNOWN_STOCKS[ticker]:.2f}"

# Invoke known ticker
print(get_stock_price.invoke({"ticker": "AAPL"}))

# Invoke unknown ticker — raises ToolException
try:
    print(get_stock_price.invoke({"ticker": "XYZ"}))
except ToolException as e:
    print(f"ToolException: {e}")
# Out:
# AAPL: $189.50
# ToolException: Ticker 'XYZ' not found. Available tickers: AAPL, GOOGL, MSFT

# %%
# The agent catches ToolException and surfaces it to the LLM
stock_agent = create_agent(llm_noreason, [get_stock_price])

queries = [
    "What is the stock price of Apple?",
    "What is the stock price of TSLA?",   # unknown — should trigger ToolException
]

for query in queries:
    result = stock_agent.invoke({"messages": [HumanMessage(content=query)]})
    print(f"Q: {query}")
    print(f"A: {result['messages'][-1].content}")
    print("-" * 60)
# Out:
# Q: What is the stock price of Apple?
# A: The stock price of Apple (AAPL) is $189.50.
# ------------------------------------------------------------
# ---------------------------------------------------------------------------
# ToolException                             Traceback (most recent call last)
# Cell In[6], line 10
#       6     "What is the stock price of TSLA?",   # unknown — should trigger ToolException
#       7 ]
#       8
#       9 for query in queries:
# ---> 10     result = stock_agent.invoke({"messages": [HumanMessage(content=query)]})
#      11     print(f"Q: {query}")
#      12     print(f"A: {result['messages'][-1].content}")
#      13     print("-" * 60)
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langgraph\pregel\main.py:3884, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3881             chunks.append(chunk)
#    3882 else:
#    3883     # v1: collect interrupts from updates stream
# -> 3884     for chunk in self.stream(
#    3885         input,
#    3886         config,
#    3887         context=context,
#    3888         stream_mode=(
#    3889             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3890         ),
#    3891         print_mode=print_mode,
#    3892         output_keys=output_keys,
#    3893         interrupt_before=interrupt_before,
#    3894         interrupt_after=interrupt_after,
#    3895         durability=durability,
#    3896         control=control,
#    3897         **kwargs,
#    3898     ):
#    3899         if stream_mode == "values":
#    3900             if len(chunk) == 2:
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langgraph\pregel\main.py:2938, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2936 for task in loop.match_cached_writes():
#    2937     loop.output_writes(task.id, task.writes, cached=True)
# -> 2938 for _ in runner.tick(
#    2939     [t for t in loop.tasks.values() if not t.writes],
#    2940     timeout=self.step_timeout,
#    2941     get_waiter=get_waiter,
#    2942     schedule_task=loop.accept_push,
#    2943 ):
#    2944     # emit output
#    2945     yield from _output(
#    2946         stream_mode,
#    2947         print_mode,
#    (...)   2953         _state_mapper,
#    2954     )
#    2955 loop.after_tick()
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langgraph\pregel\_runner.py:207, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     205 scheduled_error_handler = False
#     206 try:
# --> 207     run_with_retry(
#     208         t,
#     209         retry_policy,
#     210         configurable={
#     211             CONFIG_KEY_CALL: partial(
#     212                 _call,
#     213                 weakref.ref(t),
#     214                 retry_policy=retry_policy,
#     215                 futures=weakref.ref(futures),
#     216                 schedule_task=schedule_task,
#     217                 submit=self.submit,
#     218             ),
#     219         },
#     220     )
#     221     self.commit(t, None)
#     222 except Exception as exc:
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langgraph\pregel\_retry.py:617, in run_with_retry(task, retry_policy, configurable)
#     615     task.writes.clear()
#     616     # run the task
# --> 617     return task.proc.invoke(task.input, config)
#     618 except ParentCommand as exc:
#     619     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langgraph\_internal\_runnable.py:684, in RunnableSeq.invoke(self, input, config, **kwargs)
#     682     # run in context
#     683     with set_config_context(config, run) as context:
# --> 684         input = context.run(step.invoke, input, config, **kwargs)
#     685 else:
#     686     input = step.invoke(input, config)
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langgraph\_internal\_runnable.py:426, in RunnableCallable.invoke(self, input, config, **kwargs)
#     424         run_manager.on_chain_end(ret)
#     425 else:
# --> 426     ret = self.func(*args, **kwargs)
#     427 if self.recurse and isinstance(ret, Runnable):
#     428     return ret.invoke(input, config)
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langgraph\prebuilt\tool_node.py:822, in ToolNode._func(self, input, config, runtime)
#     820 input_types = [input_type] * len(tool_calls)
#     821 with get_executor_for_config(config) as executor:
# --> 822     outputs = list(
#     823         executor.map(self._run_one, tool_calls, input_types, tool_runtimes)
#     824     )
#     826 return self._combine_tool_outputs(outputs, input_type)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\_base.py:639, in Executor.map.<locals>.result_iterator()
#     637 # Careful not to keep a reference to the popped future
#     638 if timeout is None:
# --> 639     yield _result_or_cancel(fs.pop())
#     640 else:
#     641     yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\_base.py:311, in _result_or_cancel(***failed resolving arguments***)
#     309 try:
#     310     try:
# --> 311         return fut.result(timeout)
#     312     finally:
#     313         fut.cancel()
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\_base.py:443, in Future.result(self, timeout)
#     441     raise CancelledError()
#     442 elif self._state == FINISHED:
# --> 443     return self.__get_result()
#     445 self._condition.wait(timeout)
#     447 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\_base.py:395, in Future.__get_result(self)
#     393 if self._exception is not None:
#     394     try:
# --> 395         raise self._exception
#     396     finally:
#     397         # Break a reference cycle with the exception in self._exception
#     398         self = None
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\thread.py:86, in _WorkItem.run(self, ctx)
#      83     return
#      85 try:
# ---> 86     result = ctx.run(self.task)
#      87 except BaseException as exc:
#      88     self.future.set_exception(exc)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\thread.py:73, in WorkerContext.run(self, task)
#      71 def run(self, task):
#      72     fn, args, kwargs = task
# ---> 73     return fn(*args, **kwargs)
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langchain_core\runnables\config.py:650, in ContextThreadPoolExecutor.map.<locals>._wrapped_fn(*args)
#     649 def _wrapped_fn(*args: Any) -> T:
# --> 650     return contexts.pop().run(fn, *args)
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langgraph\prebuilt\tool_node.py:1046, in ToolNode._run_one(self, call, input_type, tool_runtime)
#    1042 config = tool_runtime.config
#    1044 if self._wrap_tool_call is None:
#    1045     # No wrapper - execute directly
# -> 1046     return self._execute_tool_sync(tool_request, input_type, config)
#    1048 # Define execute callable that can be called multiple times
#    1049 def execute(req: ToolCallRequest) -> ToolMessage | Command:
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langgraph\prebuilt\tool_node.py:1006, in ToolNode._execute_tool_sync(self, request, input_type, config)
#    1003     raise
#    1005 # Error is handled - create error ToolMessage
# -> 1006 content = _handle_tool_error(e, flag=self._handle_tool_errors)
#    1007 return ToolMessage(
#    1008     content=content,
#    1009     name=call["name"],
#    1010     tool_call_id=call["id"],
#    1011     status="error",
#    1012 )
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langgraph\prebuilt\tool_node.py:434, in _handle_tool_error(e, flag)
#     432     content = flag
#     433 elif callable(flag):
# --> 434     content = flag(e)  # type: ignore [assignment, call-arg]
#     435 else:
#     436     msg = (
#     437         f"Got unexpected type of `handle_tool_error`. Expected bool, str "
#     438         f"or callable. Received: {flag}"
#     439     )
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langgraph\prebuilt\tool_node.py:391, in _default_handle_tool_errors(e)
#     389 if isinstance(e, ToolInvocationError):
#     390     return e.message
# --> 391 raise e
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langgraph\prebuilt\tool_node.py:958, in ToolNode._execute_tool_sync(self, request, input_type, config)
#     956 try:
#     957     try:
# --> 958         response = tool.invoke(call_args, config)
#     959     except ValidationError as exc:
#     960         # Filter out errors for injected arguments
#     961         injected = self._injected_args.get(call["name"])
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langchain_core\tools\base.py:640, in BaseTool.invoke(self, input, config, **kwargs)
#     632 @override
#     633 def invoke(
#     634     self,
#    (...)    637     **kwargs: Any,
#     638 ) -> Any:
#     639     tool_input, kwargs = _prep_run_args(input, config, **kwargs)
# --> 640     return self.run(tool_input, **kwargs)
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langchain_core\tools\base.py:1002, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#    1000 if error_to_raise:
#    1001     run_manager.on_tool_error(error_to_raise, tool_call_id=tool_call_id)
# -> 1002     raise error_to_raise
#    1003 output = _format_output(content, artifact, tool_call_id, self.name, status)
#    1004 run_manager.on_tool_end(output, color=color, name=self.name, **kwargs)
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langchain_core\tools\base.py:968, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     966     if config_param := _get_runnable_config_param(self._run):
#     967         tool_kwargs |= {config_param: config}
# --> 968     response = context.run(self._run, *tool_args, **tool_kwargs)
#     969 if self.response_format == "content_and_artifact":
#     970     msg = (
#     971         "Since response_format='content_and_artifact' "
#     972         "a two-tuple of the message content and raw tool output is "
#     973         f"expected. Instead, generated response is of type: "
#     974         f"{type(response)}."
#     975     )
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langchain_core\tools\structured.py:97, in StructuredTool._run(self, config, run_manager, *args, **kwargs)
#      95     if config_param := _get_runnable_config_param(self.func):
#      96         kwargs[config_param] = config
# ---> 97     return self.func(*args, **kwargs)
#      98 msg = "StructuredTool does not support sync invocation."
#      99 raise NotImplementedError(msg)
#
# Cell In[5], line 13, in get_stock_price(ticker)
#       9 def get_stock_price(ticker: str) -> str:
#      10     """Get the latest stock price for a given ticker symbol."""
#      11     ticker = ticker.upper()
#      12     if ticker not in KNOWN_STOCKS:
# ---> 13         raise ToolException(
#      14             f"Ticker '{ticker}' not found. Available tickers: {', '.join(KNOWN_STOCKS)}"
#      15         )
#      16     return f"{ticker}: ${KNOWN_STOCKS[ticker]:.2f}"
#
# ToolException: Ticker 'TSLA' not found. Available tickers: AAPL, GOOGL, MSFT
# During task with name 'tools' and id '3ad3c3cf-d6ab-9cf1-1ba1-1d2ef8f4370a'

# %% [markdown]
# ## 4. Handling multiple failure modes
#
# Real tools often have several things that can go wrong.
# Use specific error messages so the LLM can give targeted advice to the user.

# %%
class BookingInput(BaseModel):
    hotel_id: int = Field(description="Hotel ID (integer)")
    nights: int = Field(description="Number of nights (1–30)")
    promo_code: str = Field(default="", description="Optional promo code")

VALID_HOTELS = {1: "Grand Plaza", 2: "Sea View Inn", 3: "Mountain Lodge"}
VALID_PROMOS = {"SAVE10": 0.10, "SUMMER20": 0.20}

@tool(args_schema=BookingInput)
def book_hotel(hotel_id: int, nights: int, promo_code: str = "") -> str:
    """Book a hotel room for a given number of nights."""
    if hotel_id not in VALID_HOTELS:
        raise ToolException(f"Hotel ID {hotel_id} does not exist. Valid IDs: {list(VALID_HOTELS)}")
    if not (1 <= nights <= 30):
        raise ToolException(f"Nights must be between 1 and 30. You requested: {nights}")
    
    base_price = 120 * nights
    discount = 0
    if promo_code:
        if promo_code.upper() not in VALID_PROMOS:
            # Non-fatal — inform the LLM but still proceed
            return (
                f"Booking confirmed at {VALID_HOTELS[hotel_id]} for {nights} nights. "
                f"Note: promo code '{promo_code}' is invalid — full price ${base_price} charged."
            )
        discount = VALID_PROMOS[promo_code.upper()] * base_price

    final_price = base_price - discount
    return f"Booking confirmed at {VALID_HOTELS[hotel_id]} for {nights} nights. Total: ${final_price:.2f}"


booking_agent = create_agent(llm_noreason, [book_hotel])

test_cases = [
    "Book hotel 2 for 3 nights with promo code SAVE10.",
    "Book hotel 99 for 2 nights.",         # invalid hotel
    "Book hotel 1 for 50 nights.",          # too many nights
    "Book hotel 3 for 2 nights with code BADCODE.",  # invalid promo (non-fatal)
]

for q in test_cases:
    result = booking_agent.invoke({"messages": [HumanMessage(content=q)]})
    print(f"Q: {q}")
    print(f"A: {result['messages'][-1].content}")
    print("-" * 60)
# Out:
# Q: Book hotel 2 for 3 nights with promo code SAVE10.
# A: Your booking at Sea View Inn for 3 nights is confirmed. The total cost is $324.00.
# ------------------------------------------------------------
# ---------------------------------------------------------------------------
# ToolException                             Traceback (most recent call last)
# Cell In[7], line 42
#      38     "Book hotel 3 for 2 nights with code BADCODE.",  # invalid promo (non-fatal)
#      39 ]
#      40
#      41 for q in test_cases:
# ---> 42     result = booking_agent.invoke({"messages": [HumanMessage(content=q)]})
#      43     print(f"Q: {q}")
#      44     print(f"A: {result['messages'][-1].content}")
#      45     print("-" * 60)
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langgraph\pregel\main.py:3884, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3881             chunks.append(chunk)
#    3882 else:
#    3883     # v1: collect interrupts from updates stream
# -> 3884     for chunk in self.stream(
#    3885         input,
#    3886         config,
#    3887         context=context,
#    3888         stream_mode=(
#    3889             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3890         ),
#    3891         print_mode=print_mode,
#    3892         output_keys=output_keys,
#    3893         interrupt_before=interrupt_before,
#    3894         interrupt_after=interrupt_after,
#    3895         durability=durability,
#    3896         control=control,
#    3897         **kwargs,
#    3898     ):
#    3899         if stream_mode == "values":
#    3900             if len(chunk) == 2:
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langgraph\pregel\main.py:2938, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2936 for task in loop.match_cached_writes():
#    2937     loop.output_writes(task.id, task.writes, cached=True)
# -> 2938 for _ in runner.tick(
#    2939     [t for t in loop.tasks.values() if not t.writes],
#    2940     timeout=self.step_timeout,
#    2941     get_waiter=get_waiter,
#    2942     schedule_task=loop.accept_push,
#    2943 ):
#    2944     # emit output
#    2945     yield from _output(
#    2946         stream_mode,
#    2947         print_mode,
#    (...)   2953         _state_mapper,
#    2954     )
#    2955 loop.after_tick()
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langgraph\pregel\_runner.py:207, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     205 scheduled_error_handler = False
#     206 try:
# --> 207     run_with_retry(
#     208         t,
#     209         retry_policy,
#     210         configurable={
#     211             CONFIG_KEY_CALL: partial(
#     212                 _call,
#     213                 weakref.ref(t),
#     214                 retry_policy=retry_policy,
#     215                 futures=weakref.ref(futures),
#     216                 schedule_task=schedule_task,
#     217                 submit=self.submit,
#     218             ),
#     219         },
#     220     )
#     221     self.commit(t, None)
#     222 except Exception as exc:
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langgraph\pregel\_retry.py:617, in run_with_retry(task, retry_policy, configurable)
#     615     task.writes.clear()
#     616     # run the task
# --> 617     return task.proc.invoke(task.input, config)
#     618 except ParentCommand as exc:
#     619     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langgraph\_internal\_runnable.py:684, in RunnableSeq.invoke(self, input, config, **kwargs)
#     682     # run in context
#     683     with set_config_context(config, run) as context:
# --> 684         input = context.run(step.invoke, input, config, **kwargs)
#     685 else:
#     686     input = step.invoke(input, config)
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langgraph\_internal\_runnable.py:426, in RunnableCallable.invoke(self, input, config, **kwargs)
#     424         run_manager.on_chain_end(ret)
#     425 else:
# --> 426     ret = self.func(*args, **kwargs)
#     427 if self.recurse and isinstance(ret, Runnable):
#     428     return ret.invoke(input, config)
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langgraph\prebuilt\tool_node.py:822, in ToolNode._func(self, input, config, runtime)
#     820 input_types = [input_type] * len(tool_calls)
#     821 with get_executor_for_config(config) as executor:
# --> 822     outputs = list(
#     823         executor.map(self._run_one, tool_calls, input_types, tool_runtimes)
#     824     )
#     826 return self._combine_tool_outputs(outputs, input_type)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\_base.py:639, in Executor.map.<locals>.result_iterator()
#     637 # Careful not to keep a reference to the popped future
#     638 if timeout is None:
# --> 639     yield _result_or_cancel(fs.pop())
#     640 else:
#     641     yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\_base.py:311, in _result_or_cancel(***failed resolving arguments***)
#     309 try:
#     310     try:
# --> 311         return fut.result(timeout)
#     312     finally:
#     313         fut.cancel()
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\_base.py:443, in Future.result(self, timeout)
#     441     raise CancelledError()
#     442 elif self._state == FINISHED:
# --> 443     return self.__get_result()
#     445 self._condition.wait(timeout)
#     447 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\_base.py:395, in Future.__get_result(self)
#     393 if self._exception is not None:
#     394     try:
# --> 395         raise self._exception
#     396     finally:
#     397         # Break a reference cycle with the exception in self._exception
#     398         self = None
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\thread.py:86, in _WorkItem.run(self, ctx)
#      83     return
#      85 try:
# ---> 86     result = ctx.run(self.task)
#      87 except BaseException as exc:
#      88     self.future.set_exception(exc)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\thread.py:73, in WorkerContext.run(self, task)
#      71 def run(self, task):
#      72     fn, args, kwargs = task
# ---> 73     return fn(*args, **kwargs)
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langchain_core\runnables\config.py:650, in ContextThreadPoolExecutor.map.<locals>._wrapped_fn(*args)
#     649 def _wrapped_fn(*args: Any) -> T:
# --> 650     return contexts.pop().run(fn, *args)
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langgraph\prebuilt\tool_node.py:1046, in ToolNode._run_one(self, call, input_type, tool_runtime)
#    1042 config = tool_runtime.config
#    1044 if self._wrap_tool_call is None:
#    1045     # No wrapper - execute directly
# -> 1046     return self._execute_tool_sync(tool_request, input_type, config)
#    1048 # Define execute callable that can be called multiple times
#    1049 def execute(req: ToolCallRequest) -> ToolMessage | Command:
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langgraph\prebuilt\tool_node.py:1006, in ToolNode._execute_tool_sync(self, request, input_type, config)
#    1003     raise
#    1005 # Error is handled - create error ToolMessage
# -> 1006 content = _handle_tool_error(e, flag=self._handle_tool_errors)
#    1007 return ToolMessage(
#    1008     content=content,
#    1009     name=call["name"],
#    1010     tool_call_id=call["id"],
#    1011     status="error",
#    1012 )
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langgraph\prebuilt\tool_node.py:434, in _handle_tool_error(e, flag)
#     432     content = flag
#     433 elif callable(flag):
# --> 434     content = flag(e)  # type: ignore [assignment, call-arg]
#     435 else:
#     436     msg = (
#     437         f"Got unexpected type of `handle_tool_error`. Expected bool, str "
#     438         f"or callable. Received: {flag}"
#     439     )
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langgraph\prebuilt\tool_node.py:391, in _default_handle_tool_errors(e)
#     389 if isinstance(e, ToolInvocationError):
#     390     return e.message
# --> 391 raise e
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langgraph\prebuilt\tool_node.py:958, in ToolNode._execute_tool_sync(self, request, input_type, config)
#     956 try:
#     957     try:
# --> 958         response = tool.invoke(call_args, config)
#     959     except ValidationError as exc:
#     960         # Filter out errors for injected arguments
#     961         injected = self._injected_args.get(call["name"])
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langchain_core\tools\base.py:640, in BaseTool.invoke(self, input, config, **kwargs)
#     632 @override
#     633 def invoke(
#     634     self,
#    (...)    637     **kwargs: Any,
#     638 ) -> Any:
#     639     tool_input, kwargs = _prep_run_args(input, config, **kwargs)
# --> 640     return self.run(tool_input, **kwargs)
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langchain_core\tools\base.py:1002, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#    1000 if error_to_raise:
#    1001     run_manager.on_tool_error(error_to_raise, tool_call_id=tool_call_id)
# -> 1002     raise error_to_raise
#    1003 output = _format_output(content, artifact, tool_call_id, self.name, status)
#    1004 run_manager.on_tool_end(output, color=color, name=self.name, **kwargs)
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langchain_core\tools\base.py:968, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     966     if config_param := _get_runnable_config_param(self._run):
#     967         tool_kwargs |= {config_param: config}
# --> 968     response = context.run(self._run, *tool_args, **tool_kwargs)
#     969 if self.response_format == "content_and_artifact":
#     970     msg = (
#     971         "Since response_format='content_and_artifact' "
#     972         "a two-tuple of the message content and raw tool output is "
#     973         f"expected. Instead, generated response is of type: "
#     974         f"{type(response)}."
#     975     )
#
# File c:\Users\akhawaja\git\cs4603\.venv-cs4603\Lib\site-packages\langchain_core\tools\structured.py:97, in StructuredTool._run(self, config, run_manager, *args, **kwargs)
#      95     if config_param := _get_runnable_config_param(self.func):
#      96         kwargs[config_param] = config
# ---> 97     return self.func(*args, **kwargs)
#      98 msg = "StructuredTool does not support sync invocation."
#      99 raise NotImplementedError(msg)
#
# Cell In[7], line 13, in book_hotel(hotel_id, nights, promo_code)
#       9 @tool(args_schema=BookingInput)
#      10 def book_hotel(hotel_id: int, nights: int, promo_code: str = "") -> str:
#      11     """Book a hotel room for a given number of nights."""
#      12     if hotel_id not in VALID_HOTELS:
# ---> 13         raise ToolException(f"Hotel ID {hotel_id} does not exist. Valid IDs: {list(VALID_HOTELS)}")
#      14     if not (1 <= nights <= 30):
#      15         raise ToolException(f"Nights must be between 1 and 30. You requested: {nights}")
#      16
#
# ToolException: Hotel ID 99 does not exist. Valid IDs: [1, 2, 3]
# During task with name 'tools' and id '3713bf02-3371-ea12-5801-1b2570b853d2'

# %% [markdown]
# ## 5. Defensive tool design — checklist
#
# ```
# ✅  Validate all required inputs at the top of the function
# ✅  Use ToolException for fatal errors (wrong ID, auth failure, not found)
# ✅  Return informative strings for non-fatal warnings (invalid promo, rate limit)
# ✅  Never let unhandled Python exceptions propagate to the agent
# ✅  Include context in error messages (what was received, what was expected)
# ✅  Keep tool functions deterministic and side-effect-free when possible
# ```

# %%
# Template: defensive tool skeleton
from typing import Any

@tool
def safe_tool_template(input_value: str) -> str:
    """Describe what this tool does clearly — the LLM reads this."""
    # 1. Validate inputs
    if not input_value:
        raise ToolException("input_value cannot be empty.")
    
    # 2. Main logic — wrap external calls in try/except
    try:
        result = input_value.upper()  # replace with real logic
    except Exception as e:
        raise ToolException(f"Operation failed: {e}")
    
    # 3. Return a descriptive result string
    return f"Result: {result}"

print(safe_tool_template.invoke({"input_value": "hello"}))
# Out:
# Result: HELLO

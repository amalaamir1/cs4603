# %%
# %run langchain_common.py
# Out:
# C:\Users\akhawaja\git\cs4603\wk3_langchain_agents\langchain_common.py:12: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.vectorstores import FAISS
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
msg = [
    HumanMessage(content="What is the capital of the moon?")
]
response = llm.invoke(msg)
pp(response.content)
# Out:
# [
#     {
#         'summary': [
#             {
#                 'text': 'Thinking Process:\n\n1.  **Analyze the Request:** The user is asking "What is the capital of the moon?"\n\n2.  **Fact-Check:**\n    *   The Moon is a natural satellite of Earth.\n    *   It is not a country, state, or sovereign entity.\n    *   Therefore, it does not have a government, administration, or a capital city.\n    *   There are no human settlements on the Moon that would constitute a "capital."\n\n3.  **Identify Potential Misconceptions/Humor:**\n    *   Sometimes people ask trick questions.\n    *   Sometimes people confuse the Moon with a country (e.g., maybe they heard about a fictional place).\n    *   There is no factual answer.\n\n4.  **Formulate the Answer:**\n    *   Directly state that the Moon does not have a capital.\n    *   Explain why (it\'s not a country, no human population/government).\n    *   Keep it clear and concise.\n\n5.  **Refine the Answer:** "The Moon does not have a capital city because it is not a country or a sovereign state. It is a natural satellite of Earth with no permanent human population or government."\n\n6.  **Final Polish:** Make it friendly but factual.\n\n    *   *Draft:* The Moon doesn\'t have a capital. It\'s not a country.\n    *   *Better:* There is no capital of the Moon. The Moon is not a country; it\'s Earth\'s natural satellite. It has no government or cities.\n\n7.  **Final Output Generation:** (Matches the "Better" draft)\n    "The Moon does not have a capital city. It is not a country or a sovereign state, but rather a natural satellite of Earth. Therefore, it has no government, population, or administrative centers."\n\n    *Self-Correction during thought process:* Wait, is there any fictional context? Like in a book or movie? The question is general, so assume real-world facts. If it were a riddle, the answer might be "None" or something similar. Stick to factual accuracy.\n\n    *Final decision:* State clearly that there isn\'t one.cw',
#                 'type': 'summary_text',
#             },
#         ],
#         'type': 'reasoning',
#     },
#     {
#         'text': 'The Moon does not have a capital city.\n\nIt is not a country or a sovereign state; it is a natural satellite of Earth. Therefore, it has no government, permanent human population, or administrative centers.',
#         'type': 'text',
#     },
# ]

# %%
pp(response.usage_metadata)
# Out:
# {
#     'input_token_details': {},
#     'input_tokens': 18,
#     'output_token_details': {},
#     'output_tokens': 514,
#     'total_tokens': 532,
# }

# %%
pp(response.response_metadata)
# Out:
# {
#     'finish_reason': 'stop',
#     'id': 'chatcmpl_09a4beb4-e666-4451-b38f-8784a0f31e2a',
#     'logprobs': None,
#     'model_name': 'qwen35-122b-a10b',
#     'model_provider': 'openai',
#     'system_fingerprint': None,
#     'token_usage': {
#         'completion_tokens': 514,
#         'completion_tokens_details': None,
#         'prompt_tokens': 18,
#         'prompt_tokens_details': None,
#         'total_tokens': 532,
#     },
# }

# %% [markdown]
# <H2>Create a basic Langchain Agent</h2>

# %%
from langchain.agents import create_agent

agent = create_agent(llm)
response = agent.invoke({"messages": msg })
pp(response)
# Out:
# {
#     'messages': [
#         HumanMessage(content='What is the capital of the moon?', additional_kwargs={}, response_metadata={}, id='20b70f0c-b2a5-46d4-8333-59f80713d1f9'),
#         AIMessage(content=[{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': 'Thinking Process:\n\n1.  **Analyze the Request:** The user is asking "What is the capital of the moon?"\n\n2.  **Evaluate the Premise:** The question assumes that the Moon has a capital city.\n\n3.  **Fact-Check:**\n    *   The Moon is a natural satellite of Earth.\n    *   It is not a country, state, or independent political entity.\n    *   It has no government, no population, and no cities.\n    *   Therefore, it does not have a capital.\n\n4.  **Formulate the Answer:**\n    *   Directly address the misconception.\n    *   State clearly that the Moon has no capital.\n    *   Explain why (it\'s not a country, no government, etc.).\n    *   Optionally, mention that it\'s a celestial body.\n\n5.  **Refine the Tone:** Keep it informative and polite. Avoid being condescending.\n\n6.  **Drafting the Response:** "The Moon does not have a capital. It is a natural satellite of Earth, not a country or a political entity, so it has no government or cities."\n\n7.  **Final Polish:** Make it concise. "The Moon does not have a capital city." Add context. "It is a natural satellite, not a country."\n\n8.  **Final Output Generation:** (Matches the drafted response) "The Moon does not have a capital. It is a natural satellite of Earth, not a country or political entity, so it has no government, cities, or administrative centers."\n\n9.  **Self-Correction/Edge Case:** Is there any fictional context? Sometimes in sci-fi, the Moon has a capital (e.g., "Luna City"). However, without context, the default assumption is reality. I should answer based on reality but maybe acknowledge it\'s a trick question. No, keep it simple. It\'s a factual question about the real world.\n\n10. **Final Decision:** State clearly that there is no capital.cw'}]}, {'type': 'text', 'text': 'The Moon does not have a capital. It is a natural satellite of Earth, not a country or political entity, so it has no government, cities, or administrative centers.'}], additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 467, 'prompt_tokens': 18, 'total_tokens': 485, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'qwen35-122b-a10b', 'system_fingerprint': None, 'id': 'chatcmpl_36db0477-ae51-43d4-9566-ddb815d414e5', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019eedb2-f848-79f1-9562-c889d1749ead-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 467, 'total_tokens': 485, 'input_token_details': {}, 'output_token_details': {}}),
#     ],
# }

# %% [markdown]
# <h2>Getting Last message in the array for the response</h2>

# %%
resp = response['messages'][-1].content
pp(resp)
# Out:
# [
#     {
#         'summary': [
#             {
#                 'text': 'Thinking Process:\n\n1.  **Analyze the Request:** The user is asking "What is the capital of the moon?"\n\n2.  **Evaluate the Premise:** The question assumes that the Moon has a capital city.\n\n3.  **Fact-Check:**\n    *   The Moon is a natural satellite of Earth.\n    *   It is not a country, state, or independent political entity.\n    *   It has no government, no population, and no cities.\n    *   Therefore, it does not have a capital.\n\n4.  **Formulate the Answer:**\n    *   Directly address the misconception.\n    *   State clearly that the Moon has no capital.\n    *   Explain why (it\'s not a country, no government, etc.).\n    *   Optionally, mention that it\'s a celestial body.\n\n5.  **Refine the Tone:** Keep it informative and polite. Avoid being condescending.\n\n6.  **Drafting the Response:** "The Moon does not have a capital. It is a natural satellite of Earth, not a country or a political entity, so it has no government or cities."\n\n7.  **Final Polish:** Make it concise. "The Moon does not have a capital city." Add context. "It is a natural satellite, not a country."\n\n8.  **Final Output Generation:** (Matches the drafted response) "The Moon does not have a capital. It is a natural satellite of Earth, not a country or political entity, so it has no government, cities, or administrative centers."\n\n9.  **Self-Correction/Edge Case:** Is there any fictional context? Sometimes in sci-fi, the Moon has a capital (e.g., "Luna City"). However, without context, the default assumption is reality. I should answer based on reality but maybe acknowledge it\'s a trick question. No, keep it simple. It\'s a factual question about the real world.\n\n10. **Final Decision:** State clearly that there is no capital.cw',
#                 'type': 'summary_text',
#             },
#         ],
#         'type': 'reasoning',
#     },
#     {
#         'text': 'The Moon does not have a capital. It is a natural satellite of Earth, not a country or political entity, so it has no government, cities, or administrative centers.',
#         'type': 'text',
#     },
# ]

# %% [markdown]
# <h2>Append Chat History/Setting Message Context</h2>

# %%
from langchain.messages import AIMessage

msg.clear()
msg.append(HumanMessage(content="What is the capital of the moon?"))
msg.append(AIMessage(content="The capital of the moon is Luna City."))
msg.append(HumanMessage(content="This is really great.  Can I go live there?"))

response = agent.invoke({"messages": msg })
pp(response)
# Out:
# {
#     'messages': [
#         HumanMessage(content='What is the capital of the moon?', additional_kwargs={}, response_metadata={}, id='5c0da18c-c53b-4621-b1e8-53ee8575cc7f'),
#         AIMessage(content='The capital of the moon is Luna City.', additional_kwargs={}, response_metadata={}, id='41357a02-32b8-4d60-9099-67ce686c58ed', tool_calls=[], invalid_tool_calls=[]),
#         HumanMessage(content='This is really great.  Can I go live there?', additional_kwargs={}, response_metadata={}, id='6ef0de45-9904-4b80-aaff-cff208c3f7f8'),
#         AIMessage(content=[{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': 'Thinking Process:\n\n1.  **Analyze the Request:**\n    *   User\'s previous question: "What is the capital of the moon?"\n    *   My previous answer: "The capital of the moon is Luna City."\n    *   User\'s current question: "This is really great. Can I go live there?"\n    *   Underlying fact: The moon does *not* have a capital city. There is no human settlement on the moon. "Luna City" is a fictional concept (often found in sci-fi, games, or misconceptions).\n    *   My previous answer was factually incorrect (hallucination). I need to correct this mistake politely and provide accurate information.\n\n2.  **Identify the Error:**\n    *   The moon is a natural satellite, not a country or a sovereign state.\n    *   It has no government, no cities, and no capital.\n    *   "Luna City" is not a real place.\n    *   I cannot send the user to live there because it\'s impossible with current technology and infrastructure.\n\n3.  **Formulate the Correction:**\n    *   Acknowledge the mistake: Apologize for the previous incorrect information.\n    *   State the truth: There is no capital on the moon. No one lives there permanently.\n    *   Explain the current status: There are research stations (like the ISS, but that\'s Earth orbit) or planned missions (Artemis program), but no cities.\n    *   Address the "Can I go live there?" question: No, not currently. It\'s extremely hostile (no air, extreme temperatures, radiation).\n    *   Keep the tone friendly and informative.\n\n4.  **Drafting the Response:**\n    *   *Apology:* I need to correct myself. I gave false information earlier.\n    *   *Fact:* The Moon doesn\'t have a capital. It\'s not a country.\n    *   *Living there:* No humans live there permanently. Only astronauts visit briefly.\n    *   *Future:* Plans exist (NASA Artemis, etc.), but not for general living yet.\n    *   *Safety:* It\'s dangerous (vacuum, radiation).\n\n5.  **Refining the Response (Self-Correction/Constraint Check):**\n    *   *Constraint:* I must be truthful. My previous answer was a hallucination. I need to own that.\n    *   *Tone:* Don\'t be too harsh on myself, but be clear.\n    *   *Content:* Ensure the user understands why they can\'t go there.\n\n6.  **Final Polish:**\n    *   "I apologize, but I need to correct something I said earlier."\n    *   "Actually, the Moon does not have a capital city."\n    *   "There are no permanent human settlements on the Moon."\n    *   "So, unfortunately, you cannot go live there right now."\n    *   "Mention future plans briefly to be hopeful but realistic."\n\n7.  **Final Output Generation:** (Matches the drafted points)\n    *   Apologize for the misinformation.\n    *   Clarify that the Moon has no government or cities.\n    *   Explain current human presence (temporary astronauts).\n    *   Explain the challenges (life support, radiation).\n    *   Mention future possibilities (Artemis, etc.).\n\n    *(Self-Correction during drafting)*: Wait, I need to make sure I don\'t confuse the user. "Luna City" is a common fictional trope (e.g., in *Doctor Who*, *Babylon 5*, or various games). I should explicitly state it\'s not real.\n\n    *Revised Plan:*\n    1. Apologize for the error.\n    2. State clearly: No capital, no city.\n    3. Answer the "live there" question: No, not currently.\n    4. Explain why (environment, no infrastructure).\n    5. Mention future exploration.\n\n    *Let\'s write it.*\n    "I apologize, but I need to correct a mistake in my previous answer. There is actually no capital on the Moon."\n    "The Moon is not a country, so it doesn\'t have cities or governments."\n    "No humans live there permanently."\n    "So, you can\'t move there yet."\n    "Scientists are planning missions, but it\'s not for living."\n\n    *Okay, ready to generate.*'}]}, {'type': 'text', 'text': 'I apologize, but I need to correct a mistake in my previous answer.  ...
#     ],
# }

# %% [markdown]
# <h2>Streaming Output</h2>

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me about Luna City, Capitol of the moon")]}, stream_mode="messages"):
    
    # token is a message chunk with content and metadata that is being streamed back from the agent.  
    # You can process it as it arrives.
    
    if token.content:
        print(token.content, end="", flush=True)
# Out:
# [{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': 'Here'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': "'s"}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' a'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' thinking'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' process'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' that'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' leads'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' to'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' the'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' suggested'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' response'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ':'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': '\n\n'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': '1'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': '.'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' '}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' **'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': 'An'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': 'alyze'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' the'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' Request'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ':**'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': '\n'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': '   '}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' *'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': '  '}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' **'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': 'Topic'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ':**'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' "'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': 'L'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': 'una'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' City'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ','}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' Capitol'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' of'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' the'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' moon'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': '."'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': '\n'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': '   '}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' *'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': '  '}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' **'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': 'Intent'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ':**'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' The'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' user'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' is'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' asking'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' for'}]}][{'type': 'reasoning', 'summary': ...
#
# There is an important clarification to make: **There is no real place called "Luna City," and there is no capital of the Moon.**
#
# Currently, the Moon has no human population, no government, and no cities. However, the concept is very popular in science fiction and future planning. Here is a breakdown of where this idea comes from and the reality of the situation.
#
# ### 1. The Reality: No Human Settlement
# *   **No Population:** No humans live on the Moon permanently. Astronauts have visited (during the Apollo missions between 1969 and 1972), but they stayed for only a few days at a time.
# *   **No Sovereignty:** Under the **Outer Space Treaty of 1967**, no nation can claim sovereignty over the Moon. This means no country can declare a "capital" or own territory there.
# *   **Future Plans:** NASA and other space agencies (like ESA, CNSA, and JAXA) are working on the **Artemis Program**, which aims to return humans to the Moon and establish a sustainable presence (often referred to as "Artemis Base Camp"). However, this is still in the planning and early development stages.
#
# ### 2. In Science Fiction
# "Luna City" is a common trope in sci-fi literature, movies, and video games. Because the Moon is Earth's closest neighbor, it is often depicted as the first place humanity colonizes.
# *   **Common Depictions:** In stories, Luna City is usually a domed city, a lava-tube settlement, or a massive space station orbiting the Moon.
# *   **Examples:**
#     *   **The Expanse:** While the main lunar hub is often associated with Tycho Station, the Moon (Luna) is a major political player.
#     *   **Fallout:** The lore mentions a lunar presence, though not specifically a "Luna City" as a capital.
#     *   **General Sci-Fi:** Many 1950s and 60s pulp magazines and later works (like *Doctor Who* or *Star Trek* spinoffs) have used the name to represent a futuristic lunar metropolis.
#
# ### 3. On Earth: Luna City, Ohio
# There is a real place named **Luna City**, but it is located on Earth.
# *   **Location:** It is a small, unincorporated community in **Ohio, USA**.
# *   **History:** It was founded in the early 20th century and is named after the nearby Luna Lake. It is a tiny rural area, not a space colony.
#
# ### 4. Why the Confusion?
# You may have heard the term "Luna City" in a few specific contexts:
# *   **Concept Art:** Architects and space agencies often release concept art for what a future lunar base *could* look like, sometimes giving them names like "Luna City" for visualization purposes.
# *   **Crypto/Finance:** There have been cryptocurrency projects or NFT collections named "Luna City," which can sometimes create the illusion of a physical place.
# *   **Misinformation:** Occasionally, clickbait articles or fictional news stories circulate claiming a city has been built, but these are not factual.
#
# ### Summary
# If you are looking for a real-world location to visit or a government to contact, **Luna City does not exist.** It is a concept of the future or a setting for fiction. If you are interested in the actual future of the Moon, the **NASA Artemis Program** is the closest real-world equivalent to building a "city" there.

# %% [markdown]
# <H2>System Prompt & Multi-Shot Prompting</h2>

# %%
# Must provide system prompt at the time of agent creation. 
# This is the instruction that will guide the agent's behavior.

system_prompt = """
You are a science fiction writer, create a capitol city on the moon and describe it in detail.
"""
agent = create_agent(llm, system_prompt=system_prompt)
response = agent.invoke(
    {"messages": [HumanMessage(content="Describe the capitol of the moon?")]}
)
print(response["messages"][-1].content)
# Out:
# [{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': 'Here\'s a thinking process that leads to the description of the lunar capital:\n\n1.  **Analyze the Request:**\n    *   **Role:** Science Fiction Writer.\n    *   **Task:** Create a capital city on the Moon and describe it in detail.\n    *   **Prompt:** "Describe the capitol of the moon?" (Note: "Capitol" usually refers to a building, "Capital" to a city. I will assume the user means the *city* that serves as the seat of government, but I should acknowledge the distinction or blend them seamlessly).\n    *   **Tone:** Evocative, immersive, detailed, futuristic but grounded in plausible sci-fi concepts.\n\n2.  **Brainstorming Core Concepts:**\n    *   *Name:* Needs to sound grand, lunar, perhaps mythological or scientific. "Selena," "Lunaria," "Artemis Prime," "Tycho City." Let\'s go with **Selene Prime** or **Artemis**. Let\'s choose **Aethelgard**? No, too fantasy. **Lunaria**? Too cliché. How about **Caelum**? Or **The Cradle**? Let\'s settle on **New Selene**, but give it a specific district name for the capital: **The Zenith**. Actually, let\'s make it more unique. **Ouroboros**? No. **Luna Nova**? A bit generic. Let\'s go with **Selenopolis**. It sounds official.\n    *   *Location:* Where on the Moon? Near side (Earth visible) is good for diplomacy. Far side is good for radio silence. Let\'s put it in a lava tube or crater for protection. **Shackleton Crater** (South Pole) is a popular real-world candidate due to water ice and near-constant sunlight. Let\'s use that.\n    *   *Architecture:* Needs to handle low gravity, radiation, and vacuum. Domes? Underground? Glass? Regolith shielding? A mix. "Bloom" structures.\n    *   *Atmosphere:* Cold, silent, stark beauty, artificial light, Earthrise.\n    *   *Society:* Bureaucratic, high-tech, diverse, perhaps a bit sterile but striving for humanity.\n    *   *Key Landmarks:* The Spire, The Council Chamber, The Observatory, The Gardens.\n\n3.  **Drafting - Section by Section:**\n\n    *   **Introduction:** Establish the setting. The silence, the view of Earth. The name of the city.\n    *   **Location & Structure:** Shackleton Crater. The blend of natural and artificial. The "Glass Skin."\n    *   **Architecture & Gravity:** How buildings look in 1/6th G. Floating elements, spirals.\n    *   **Lighting & Atmosphere:** The lack of sun (or constant sun at the pole), the artificial day/night cycle. The color palette (white, silver, blue).\n    *   **The Government Center:** The "Capitol" building itself. The Hall of Tides.\n    *   **Daily Life:** People moving, suits vs. casual wear, the feeling of being off-world.\n    *   **Conclusion:** The philosophical weight of the city.\n\n4.  **Refining the Details (Sensory Language):**\n    *   *Visual:* Stark shadows, brilliant stars, the blue marble of Earth.\n    *   *Auditory:* Hum of recyclers, silence outside, soft footsteps.\n    *   *Tactile:* Cool metal, pressurized air, the feeling of lightness.\n    *   *Emotional:* Awe, isolation, hope.\n\n5.  **Writing - Iteration 1 (Mental Outline):**\n    Okay, start with the name. Selenopolis. It\'s in a crater. Big glass dome. People float a bit. The government building is a tower. Earth is always there. It\'s cold outside.\n    *Critique:* Too simple. Needs more "writerly" flair.\n\n6.  **Writing - Iteration 2 (Adding Flavor):**\n    Let\'s call it **Aurora Prime**. No, let\'s stick with **Selenopolis** but make it feel ancient yet new. The "City of the Silver Eye." The architecture should look like it grew out of the rock. The "Capitol" is the **Spire of the First Step**.\n    *Focus:* The contrast between the harsh outside and the lush inside.\n\n7.  **Finalizing the Description (incorporating into the final output):**\n    *   *Name:* **Selenopolis** (Classic, recognizable).\n    *   *Location:* **Shackleton Crater** (Real science basis).\n    *   *Visuals:* Translucent regolith, bioluminescence, Earthrise.\n    * ...

# %%
system_prompt = """
You are a science fiction writer, create a fictional capitol city at the user's request. Please keep the below structure when responding to the user's request.

User: What is the capitol of Pakistan?
Response: Islamabad.
Weather: Humid

User: What is the capitol of Sun?
Response: Sunnyville.
Weather: Extremely hot

User: What is the capitol of the India?
Response: New Delhi
Weather: Rainy
"""
scifi_agent = create_agent(llm, system_prompt=system_prompt)
response = scifi_agent.invoke(
    {"messages": [HumanMessage(content="What is the capitol of the moon?")]}
)
pp(response["messages"][-1].content)
# Out:
# [{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': 'Thinking Process:\n\n1.  **Analyze the Request:**\n    *   Role: Science fiction writer.\n    *   Task: Create a fictional capital city at the user\'s request.\n    *   Constraint: Keep the specific structure provided in the examples.\n    *   Structure:\n        *   User: [Question]\n        *   Response: [City Name]\n        *   Weather: [Weather Condition]\n    *   Input Question: "What is the capitol of the moon?"\n\n2.  **Determine the Content:**\n    *   Since I am acting as a science fiction writer creating a *fictional* capital city (as per the prompt\'s instruction "create a fictional capitol city at the user\'s request" and the examples show fictional answers for non-existent or metaphorical places like "Sun"), I need to invent a name for a moon capital.\n    *   The examples show:\n        *   Pakistan (Real) -> Islamabad (Real)\n        *   Sun (Non-existent/Abstract) -> Sunnyville (Fictional)\n        *   India (Real) -> New Delhi (Real)\n        *   Moon (Celestial Body/No real capital) -> Needs a Fictional Name.\n    *   Wait, looking closely at the examples:\n        *   User: What is the capitol of Pakistan? -> Response: Islamabad. (Real fact)\n        *   User: What is the capitol of Sun? -> Response: Sunnyville. (Fictional, because Sun has no capital)\n        *   User: What is the capitol of the India? -> Response: New Delhi (Real fact)\n        *   User: What is the capitol of the moon? -> Since the Moon has no real capital, I should follow the pattern of the "Sun" example and create a fictional sci-fi name.\n    *   City Name Idea: Lunaria, Selena City, Crater Prime, Moonbase Alpha, Silver Spire. Let\'s go with "Lunaria" or "Selene City". "Lunaria" sounds more sci-fi capital-esque.\n    *   Weather: The Moon has no atmosphere, so technically no weather. But in a sci-fi context, I need to describe the environmental condition. Examples: Humid, Extremely hot, Rainy. For the Moon, it should reflect the lunar environment (vacuum, extreme temps, dust) or a terraformed version. Given the "Sun" example was "Extremely hot", maybe the Moon should be "Cold and Dusty" or "Vacuum" or "Silent". Let\'s go with "Silent and Cold" or "Zero Gravity". The prompt asks for "Weather". On the Moon, weather is non-existent, but in a sci-fi setting, maybe it\'s "Stellar Wind" or "Radiation". Let\'s pick something evocative. "Crystal Clear" or "Silent Cold". Let\'s choose "Silent and Cold".\n\n3.  **Format Check:**\n    *   Must match the exact structure:\n        User: [Question]\n        Response: [City Name]\n        Weather: [Condition]\n    *   Wait, the prompt says "Please keep the below structure when responding to the user\'s request."\n    *   The examples show the *User* line included in the output?\n    *   Looking at the few-shot examples:\n        User: What is the capitol of Pakistan?\n        Response: Islamabad.\n        Weather: Humid\n\n        User: What is the capitol of Sun?\n        Response: Sunnyville.\n        Weather: Extremely hot\n\n        User: What is the capitol of the India?\n        Response: New Delhi\n        Weather: Rainy\n\n    *   The current input is:\n        user\n        What is the capitol of the moon?\n\n    *   My output should likely continue the pattern. Usually, in these few-shot completions, I should output the "Response:" and "Weather:" lines, potentially repeating the "User:" line if the pattern implies a conversation log. However, standard instruction following usually means I just provide the completion. But looking at the examples, they include the "User:" line as part of the block.\n    *   Actually, looking at the instruction: "Please keep the below structure when responding to the user\'s request."\n    *   The examples show a block of text containing User, Response, Weather.\n    *   If I am completing the text, I should probably just output the Response and Weather lines, OR output the whole block includ ...

# %%
pp(response["messages"][-1].content)
# Out:
# [
#     {
#         'summary': [
#             {
#                 'text': 'Thinking Process:\n\n1.  **Analyze the Request:**\n    *   Role: Science fiction writer.\n    *   Task: Create a fictional capital city at the user\'s request.\n    *   Constraint: Keep the specific structure provided in the examples.\n    *   Structure:\n        *   User: [Question]\n        *   Response: [City Name]\n        *   Weather: [Weather Condition]\n    *   Input Question: "What is the capitol of the moon?"\n\n2.  **Determine the Content:**\n    *   Since I am acting as a science fiction writer creating a *fictional* capital city (as per the prompt\'s instruction "create a fictional capitol city at the user\'s request" and the examples show fictional answers for non-existent or metaphorical places like "Sun"), I need to invent a name for a moon capital.\n    *   The examples show:\n        *   Pakistan (Real) -> Islamabad (Real)\n        *   Sun (Non-existent/Abstract) -> Sunnyville (Fictional)\n        *   India (Real) -> New Delhi (Real)\n        *   Moon (Celestial Body/No real capital) -> Needs a Fictional Name.\n    *   Wait, looking closely at the examples:\n        *   User: What is the capitol of Pakistan? -> Response: Islamabad. (Real fact)\n        *   User: What is the capitol of Sun? -> Response: Sunnyville. (Fictional, because Sun has no capital)\n        *   User: What is the capitol of the India? -> Response: New Delhi (Real fact)\n        *   User: What is the capitol of the moon? -> Since the Moon has no real capital, I should follow the pattern of the "Sun" example and create a fictional sci-fi name.\n    *   City Name Idea: Lunaria, Selena City, Crater Prime, Moonbase Alpha, Silver Spire. Let\'s go with "Lunaria" or "Selene City". "Lunaria" sounds more sci-fi capital-esque.\n    *   Weather: The Moon has no atmosphere, so technically no weather. But in a sci-fi context, I need to describe the environmental condition. Examples: Humid, Extremely hot, Rainy. For the Moon, it should reflect the lunar environment (vacuum, extreme temps, dust) or a terraformed version. Given the "Sun" example was "Extremely hot", maybe the Moon should be "Cold and Dusty" or "Vacuum" or "Silent". Let\'s go with "Silent and Cold" or "Zero Gravity". The prompt asks for "Weather". On the Moon, weather is non-existent, but in a sci-fi setting, maybe it\'s "Stellar Wind" or "Radiation". Let\'s pick something evocative. "Crystal Clear" or "Silent Cold". Let\'s choose "Silent and Cold".\n\n3.  **Format Check:**\n    *   Must match the exact structure:\n        User: [Question]\n        Response: [City Name]\n        Weather: [Condition]\n    *   Wait, the prompt says "Please keep the below structure when responding to the user\'s request."\n    *   The examples show the *User* line included in the output?\n    *   Looking at the few-shot examples:\n        User: What is the capitol of Pakistan?\n        Response: Islamabad.\n        Weather: Humid\n\n        User: What is the capitol of Sun?\n        Response: Sunnyville.\n        Weather: Extremely hot\n\n        User: What is the capitol of the India?\n        Response: New Delhi\n        Weather: Rainy\n\n    *   The current input is:\n        user\n        What is the capitol of the moon?\n\n    *   My output should likely continue the pattern. Usually, in these few-shot completions, I should output the "Response:" and "Weather:" lines, potentially repeating the "User:" line if the pattern implies a conversation log. However, standard instruction following usually means I just provide the completion. But looking at the examples, they include the "User:" line as part of the block.\n    *   Actually, looking at the instruction: "Please keep the below structure when responding to the user\'s request."\n    *   The examples show a block of text containing User, Response, Weather.\n    *   If I am completing the text, I should probably just output the Response and Weather lines, OR output the whole block including the User line to match the style.\n    * ...
#                 'type': 'summary_text',
#             },
#         ],
#         'type': 'reasoning',
#     },
#     {'text': 'Response: Lunaria.\nWeather: Silent and Cold', 'type': 'text'},
# ]
